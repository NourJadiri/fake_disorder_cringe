# %% [markdown]
# ### first approach for Mistrale (Let's Hope)

# %% [markdown]
# ######  Do the login to hugging face and get the acess Tokin in order to get the model of mistral
# - !huggingface-cli login

# %%
from vllm import LLM, SamplingParams

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

llm = LLM(model="mistralai/Mistral-7B-v0.1", dtype="float16").to(device)
# Out:
# WARNING 12-13 19:08:24 config.py:1865] Casting torch.bfloat16 to torch.float16.
# INFO 12-13 19:08:24 config.py:350] This model supports multiple tasks: {'generate', 'embedding'}. Defaulting to 'generate'.
# WARNING 12-13 19:08:24 config.py:791] Possibly too large swap space. 4.00 GiB out of the 7.71 GiB total CPU memory is allocated for the swap space.
# INFO 12-13 19:08:24 llm_engine.py:249] Initializing an LLM engine (v0.6.4.post1) with config: model='mistralai/Mistral-7B-v0.1', speculative_config=None, tokenizer='mistralai/Mistral-7B-v0.1', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=mistralai/Mistral-7B-v0.1, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, chat_template_text_format=string, mm_processor_kwargs=None, pooler_config=None)
# INFO 12-13 19:08:25 model_runner.py:1072] Starting to load model mistralai/Mistral-7B-v0.1...
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[16], line 3
#       1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ----> 3 llm = LLM(model="mistralai/Mistral-7B-v0.1", dtype="float16").to(device)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/utils.py:1028, in deprecate_args.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#    1021             msg += f" {additional_message}"
#    1023         warnings.warn(
#    1024             DeprecationWarning(msg),
#    1025             stacklevel=3,  # The inner function takes up one level
#    1026         )
# -> 1028 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/entrypoints/llm.py:210, in LLM.__init__(self, model, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, allowed_local_media_path, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, seed, gpu_memory_utilization, swap_space, cpu_offload_gb, enforce_eager, max_seq_len_to_capture, disable_custom_all_reduce, disable_async_output_proc, hf_overrides, mm_processor_kwargs, task, override_pooler_config, **kwargs)
#     207 self.engine_class = self.get_engine_class()
#     209 # TODO(rob): enable mp by default (issue with fork vs spawn)
# --> 210 self.llm_engine = self.engine_class.from_engine_args(
#     211     engine_args, usage_context=UsageContext.LLM_CLASS)
#     213 self.request_counter = Counter()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/engine/llm_engine.py:585, in LLMEngine.from_engine_args(cls, engine_args, usage_context, stat_loggers)
#     583 executor_class = cls._get_executor_cls(engine_config)
#     584 # Create the LLM engine.
# --> 585 engine = cls(
#     586     vllm_config=engine_config,
#     587     executor_class=executor_class,
#     588     log_stats=not engine_args.disable_log_stats,
#     589     usage_context=usage_context,
#     590     stat_loggers=stat_loggers,
#     591 )
#     593 return engine
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/engine/llm_engine.py:347, in LLMEngine.__init__(self, vllm_config, executor_class, log_stats, usage_context, stat_loggers, input_registry, mm_registry, use_cached_outputs)
#     343 self.input_registry = input_registry
#     344 self.input_processor = input_registry.create_input_processor(
#     345     model_config)
# --> 347 self.model_executor = executor_class(vllm_config=vllm_config, )
#     349 if self.model_config.task != "embedding":
#     350     self._initialize_kv_caches()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/executor/executor_base.py:36, in ExecutorBase.__init__(self, vllm_config)
#      34 self.prompt_adapter_config = vllm_config.prompt_adapter_config
#      35 self.observability_config = vllm_config.observability_config
# ---> 36 self._init_executor()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/executor/gpu_executor.py:40, in GPUExecutor._init_executor(self)
#      38 self.driver_worker = self._create_worker()
#      39 self.driver_worker.init_device()
# ---> 40 self.driver_worker.load_model()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/worker/worker.py:152, in Worker.load_model(self)
#     151 def load_model(self):
# --> 152     self.model_runner.load_model()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/worker/model_runner.py:1074, in GPUModelRunnerBase.load_model(self)
#    1072 logger.info("Starting to load model %s...", self.model_config.model)
#    1073 with DeviceMemoryProfiler() as m:
# -> 1074     self.model = get_model(vllm_config=self.vllm_config)
#    1076 self.model_memory_usage = m.consumed_memory
#    1077 logger.info("Loading model weights took %.4f GB",
#    1078             self.model_memory_usage / float(2**30))
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/model_loader/__init__.py:12, in get_model(vllm_config)
#      10 def get_model(*, vllm_config: VllmConfig) -> nn.Module:
#      11     loader = get_model_loader(vllm_config.load_config)
# ---> 12     return loader.load_model(vllm_config=vllm_config)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/model_loader/loader.py:332, in DefaultModelLoader.load_model(self, vllm_config)
#     330 with set_default_torch_dtype(model_config.dtype):
#     331     with target_device:
# --> 332         model = _initialize_model(vllm_config=vllm_config)
#     334     model.load_weights(self._get_all_weights(model_config, model))
#     336     for _, module in model.named_modules():
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/model_loader/loader.py:100, in _initialize_model(vllm_config, prefix)
#      97 all_params = [param.name for param in signatures.parameters.values()]
#      98 if "vllm_config" in all_params and "prefix" in all_params:
#      99     # new-style model class
# --> 100     return model_class(vllm_config=vllm_config, prefix=prefix)
#     101 msg = ("vLLM model class should accept `vllm_config` and `prefix` as "
#     102        "input arguments. Possibly you have an old-style model class"
#     103        " registered from out of tree and it is used for new vLLM version. "
#     104        "Check https://docs.vllm.ai/en/latest/design/class_hierarchy.html "
#     105        "for the design and update the model class accordingly.")
#     106 logger.warning(msg)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/models/llama.py:503, in LlamaForCausalLM.__init__(self, vllm_config, prefix)
#     500 self.config = config
#     501 self.lora_config = lora_config
# --> 503 self.model = LlamaModel(vllm_config=vllm_config,
#     504                         prefix=maybe_prefix(prefix, "model"))
#     505 if get_pp_group().is_last_rank:
#     506     self.unpadded_vocab_size = config.vocab_size
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/compilation/decorators.py:126, in _support_torch_compile.<locals>.__init__(self, vllm_config, prefix, **kwargs)
#     125 def __init__(self, *, vllm_config: VllmConfig, prefix: str = '', **kwargs):
# --> 126     old_init(self, vllm_config=vllm_config, prefix=prefix, **kwargs)
#     127     # for CompilationLevel.DYNAMO_AS_IS , the upper level model runner
#     128     # will handle the compilation, so we don't need to do anything here.
#     129     self.do_not_compile = envs.VLLM_TORCH_COMPILE_LEVEL in [
#     130         CompilationLevel.NO_COMPILATION, CompilationLevel.DYNAMO_AS_IS
#     131     ] or not supports_dynamo()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/models/llama.py:298, in LlamaModel.__init__(self, vllm_config, prefix)
#     296 else:
#     297     self.embed_tokens = PPMissingLayer()
# --> 298 self.start_layer, self.end_layer, self.layers = make_layers(
#     299     config.num_hidden_layers,
#     300     lambda prefix: LlamaDecoderLayer(config=config,
#     301                                      cache_config=cache_config,
#     302                                      quant_config=quant_config,
#     303                                      prefix=prefix),
#     304     prefix=f"{prefix}.layers",
#     305 )
#     306 if get_pp_group().is_last_rank:
#     307     self.norm = RMSNorm(config.hidden_size, eps=config.rms_norm_eps)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/models/utils.py:510, in make_layers(num_hidden_layers, layer_fn, prefix)
#     504 from vllm.distributed.utils import get_pp_indices
#     505 start_layer, end_layer = get_pp_indices(num_hidden_layers,
#     506                                         get_pp_group().rank_in_group,
#     507                                         get_pp_group().world_size)
#     508 modules = torch.nn.ModuleList(
#     509     [PPMissingLayer() for _ in range(start_layer)] + [
# --> 510         maybe_offload_to_cpu(layer_fn(prefix=f"{prefix}.{idx}"))
#     511         for idx in range(start_layer, end_layer)
#     512     ] + [PPMissingLayer() for _ in range(end_layer, num_hidden_layers)])
#     513 return start_layer, end_layer, modules
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/models/llama.py:300, in LlamaModel.__init__.<locals>.<lambda>(prefix)
#     296 else:
#     297     self.embed_tokens = PPMissingLayer()
#     298 self.start_layer, self.end_layer, self.layers = make_layers(
#     299     config.num_hidden_layers,
# --> 300     lambda prefix: LlamaDecoderLayer(config=config,
#     301                                      cache_config=cache_config,
#     302                                      quant_config=quant_config,
#     303                                      prefix=prefix),
#     304     prefix=f"{prefix}.layers",
#     305 )
#     306 if get_pp_group().is_last_rank:
#     307     self.norm = RMSNorm(config.hidden_size, eps=config.rms_norm_eps)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/models/llama.py:231, in LlamaDecoderLayer.__init__(self, config, cache_config, quant_config, prefix)
#     215 attention_bias = getattr(config, "attention_bias", False) or getattr(
#     216     config, "bias", False)
#     217 self.self_attn = LlamaAttention(
#     218     config=config,
#     219     hidden_size=self.hidden_size,
#    (...)
#     229     prefix=f"{prefix}.self_attn",
#     230 )
# --> 231 self.mlp = LlamaMLP(
#     232     hidden_size=self.hidden_size,
#     233     intermediate_size=config.intermediate_size,
#     234     hidden_act=config.hidden_act,
#     235     quant_config=quant_config,
#     236     bias=getattr(config, "mlp_bias", False),
#     237     prefix=f"{prefix}.mlp",
#     238 )
#     239 self.input_layernorm = RMSNorm(config.hidden_size,
#     240                                eps=config.rms_norm_eps)
#     241 self.post_attention_layernorm = RMSNorm(config.hidden_size,
#     242                                         eps=config.rms_norm_eps)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/models/llama.py:73, in LlamaMLP.__init__(self, hidden_size, intermediate_size, hidden_act, quant_config, bias, prefix)
#      63 def __init__(
#      64     self,
#      65     hidden_size: int,
#    (...)
#      70     prefix: str = "",
#      71 ) -> None:
#      72     super().__init__()
# ---> 73     self.gate_up_proj = MergedColumnParallelLinear(
#      74         input_size=hidden_size,
#      75         output_sizes=[intermediate_size] * 2,
#      76         bias=bias,
#      77         quant_config=quant_config,
#      78         prefix=f"{prefix}.gate_up_proj",
#      79     )
#      80     self.down_proj = RowParallelLinear(
#      81         input_size=intermediate_size,
#      82         output_size=hidden_size,
#    (...)
#      85         prefix=f"{prefix}.down_proj",
#      86     )
#      87     if hidden_act != "silu":
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/layers/linear.py:424, in MergedColumnParallelLinear.__init__(self, input_size, output_sizes, bias, gather_output, skip_bias_add, params_dtype, quant_config, prefix)
#     422 tp_size = get_tensor_model_parallel_world_size()
#     423 assert all(output_size % tp_size == 0 for output_size in output_sizes)
# --> 424 super().__init__(input_size=input_size,
#     425                  output_size=sum(output_sizes),
#     426                  bias=bias,
#     427                  gather_output=gather_output,
#     428                  skip_bias_add=skip_bias_add,
#     429                  params_dtype=params_dtype,
#     430                  quant_config=quant_config,
#     431                  prefix=prefix)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/layers/linear.py:304, in ColumnParallelLinear.__init__(self, input_size, output_size, bias, gather_output, skip_bias_add, params_dtype, quant_config, output_sizes, prefix)
#     301 if output_sizes is None:
#     302     output_sizes = [output_size]
# --> 304 self.quant_method.create_weights(
#     305     layer=self,
#     306     input_size_per_partition=self.input_size,
#     307     output_partition_sizes=self.output_partition_sizes,
#     308     input_size=self.input_size,
#     309     output_size=self.output_size,
#     310     params_dtype=self.params_dtype,
#     311     weight_loader=(
#     312         self.weight_loader_v2 if self.quant_method.__class__.__name__
#     313         in WEIGHT_LOADER_V2_SUPPORTED else self.weight_loader))
#     314 if bias:
#     315     self.bias = Parameter(
#     316         torch.empty(self.output_size_per_partition,
#     317                     dtype=params_dtype))
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/vllm/model_executor/layers/linear.py:122, in UnquantizedLinearMethod.create_weights(self, layer, input_size_per_partition, output_partition_sizes, input_size, output_size, params_dtype, **extra_weight_attrs)
#     117 def create_weights(self, layer: torch.nn.Module,
#     118                    input_size_per_partition: int,
#     119                    output_partition_sizes: List[int], input_size: int,
#     120                    output_size: int, params_dtype: torch.dtype,
#     121                    **extra_weight_attrs):
# --> 122     weight = Parameter(torch.empty(sum(output_partition_sizes),
#     123                                    input_size_per_partition,
#     124                                    dtype=params_dtype),
#     125                        requires_grad=False)
#     126     set_weight_attrs(weight, {"input_dim": 1, "output_dim": 0})
#     127     layer.register_parameter("weight", weight)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/torch/utils/_device.py:106, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     104 if func in _device_constructors() and kwargs.get('device') is None:
#     105     kwargs['device'] = self.device
# --> 106 return func(*args, **kwargs)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 224.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Including non-PyTorch memory, this process has 17179869184.00 GiB memory in use. Of the allocated memory 10.89 GiB is allocated by PyTorch, and 13.59 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# Load and run the model:
vllm serve "mistralai/Mistral-7B-v0.1"
# Out:
#   Cell In[9], line 2
#     vllm serve "mistralai/Mistral-7B-v0.1"
#          ^
# SyntaxError: invalid syntax

# %%
import torch
torch.cuda.empty_cache()

# %%
if 'tensor' in locals():
    del tensor
    torch.cuda.empty_cache()
